# %%
import json
from tqdm import tqdm
import pandas as pd
from simpletransformers.classification import MultiLabelClassificationModel
from sklearn.preprocessing import MultiLabelBinarizer
import numpy as np
import torch
from sklearn.model_selection import train_test_split

import random

import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
import seaborn as sns
from sklearn.metrics import confusion_matrix

# %%
import psycopg2

con = psycopg2.connect(
  database="dsa1", 
  user="dsa1", 
  password="HSEPAassword2022", 
  host="77.37.164.38", 
  port="5432"
)

# %%
cur = con.cursor()
cur.execute("SELECT * from MIEM_PROJECTS")
rows = cur.fetchall()
column_names=["ID","NUMBER","VACANCIES","NAME","TYPE","TYPEDESC","TYPEID","STATUSID", "STATUSDESC","DIRECTIONHEAD","HEAD","DATACREATED","FACULTYID"]
df = pd.DataFrame(rows, columns=column_names)
df.head()
# Out:
#      ID  NUMBER  VACANCIES                                               NAME  \
# 0   852     NaN          2  Приготовление квантовых состояний для систем к...
# 1   853     NaN          2  Создание системы квантового распределения ключ...
# 2   869     NaN          5  Разработка функциональной модели IP-блока (Сло...
# 3   967     NaN          1  Течение жидкостей в криволинейных трубах и кан...
# 4  1026     NaN          2  Научные исследования в группе «Ультрахолодные ...
#
#       TYPE TYPEDESC  TYPEID  STATUSID      STATUSDESC DIRECTIONHEAD  \
# 0      nir      НИР       1         1  Готов к работе
# 1      nir      НИР       1         1  Готов к работе
# 2  startup  Стартап       4         1  Готов к работе
# 3      nir      НИР       1         1  Готов к работе
# 4      nir      НИР       1         1  Готов к работе
#
#                            HEAD          DATACREATED FACULTYID
# 0                 Шаховой Роман  10.08.2021 16:25:36      None
# 1          Дуплинский Александр  10.08.2021 16:29:38      None
# 2       Нефедов Сергей Игоревич  26.08.2021 14:32:28      None
# 3  Данилов Владимир Григорьевич  30.09.2021 18:45:31      None
# 4               Турлапов Андрей  20.10.2021 13:00:06      None

# %%
df.shape
# Out:
# (441, 13)

# %%
papers = pd.DataFrame({
    'title': df['NAME'].tolist(),
    'categories': df['TYPE'].tolist()
})

papers['title'] = papers['title'].apply(lambda x: x.replace("\n",""))
papers['title'] = papers['title'].apply(lambda x: x.strip())
papers['text'] = papers['title']

papers['categories'] = papers['categories'].apply(lambda x: tuple(x.split()))

shortlisted_categories = papers['categories'].value_counts().reset_index(name="count").query("count > 0")["index"].tolist()
papers = papers[papers["categories"].isin(shortlisted_categories)].reset_index(drop=True)

papers = papers.sample(frac=1).reset_index(drop=True)

papers = papers.groupby('categories').head(250).reset_index(drop=True)

multi_label_encoder = MultiLabelBinarizer()
multi_label_encoder.fit(papers['categories'])
papers['categories_encoded'] = papers['categories'].apply(lambda x: multi_label_encoder.transform([x])[0])

papers = papers[["text", "categories", "categories_encoded"]]
papers.head()
# Out:
#                                                 text    categories  \
# 0  Многофункциональный сценарный контроллер освещ...  (soft-hard,)
# 1  Разработка и реализация методов идентификации ...       (soft,)
# 2             Виртуальный космос виртуальный спутник       (soft,)
# 3  Элементы сверхпроводящей спинтроники для приме...        (nir,)
# 4  Исследование электрических и механических свой...        (nir,)
#
#   categories_encoded
# 0       [0, 0, 1, 0]
# 1       [0, 1, 0, 0]
# 2       [0, 1, 0, 0]
# 3       [1, 0, 0, 0]
# 4       [1, 0, 0, 0]

# %%
papers.shape
# Out:
# (441, 3)

# %%
train, test = train_test_split(papers, test_size=0.3, stratify=papers['categories'], random_state=42)

# %% [markdown]
# Модель:

# %%
model_args = {
    "reprocess_input_data": True,
    "overwrite_output_dir": True,
    "save_model_every_epoch": False,
    "save_eval_checkpoints": False,
    "max_seq_length": 512,
    "train_batch_size": 4,
    "num_train_epochs": 4,
}

model = MultiLabelClassificationModel('xlnet', 
                                      'xlnet-base-cased', 
                                      num_labels=len(shortlisted_categories), 
                                      args=model_args)
# Out:
# Downloading:   0%|          | 0.00/760 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/445M [00:00<?, ?B/s]
# Some weights of the model checkpoint at xlnet-base-cased were not used when initializing XLNetForMultiLabelSequenceClassification: ['lm_loss.bias', 'lm_loss.weight']
# - This IS expected if you are initializing XLNetForMultiLabelSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLNetForMultiLabelSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of XLNetForMultiLabelSequenceClassification were not initialized from the model checkpoint at xlnet-base-cased and are newly initialized: ['logits_proj.weight', 'sequence_summary.summary.weight', 'logits_proj.bias', 'sequence_summary.summary.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading:   0%|          | 0.00/779k [00:00<?, ?B/s]

# %%
model.train_model(train[['text', 'categories_encoded']])
# Out:
# /opt/conda/lib/python3.7/site-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/308 [00:00<?, ?it/s]
# /opt/conda/lib/python3.7/site-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/4 [00:00<?, ?it/s]
# Running Epoch 0 of 4:   0%|          | 0/77 [00:00<?, ?it/s]
# /opt/conda/lib/python3.7/site-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# Running Epoch 1 of 4:   0%|          | 0/77 [00:00<?, ?it/s]
# Running Epoch 2 of 4:   0%|          | 0/77 [00:00<?, ?it/s]
# Running Epoch 3 of 4:   0%|          | 0/77 [00:00<?, ?it/s]
# (308, 0.42858467231710234)

# %%
result, model_outputs, wrong_predictions = model.eval_model(test[['text', 'categories_encoded']])
print(result)
# Out:
# /opt/conda/lib/python3.7/site-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/133 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/17 [00:00<?, ?it/s]
# {'LRAP': 0.763157894736842, 'eval_loss': 0.4243993268293493}

# %%
for _ in range(5):

    random_idx = random.randint(0, len(test)-1)
    text = test.iloc[random_idx]['text']
    true_categories = test.iloc[random_idx]['categories']

    predicted_categories_encoded, raw_outputs = model.predict([text])
    predicted_categories_encoded = np.array(predicted_categories_encoded)
    predicted_categories_encoded[0][np.argmax(raw_outputs[0])] = 1
    predicted_categories = multi_label_encoder.inverse_transform(predicted_categories_encoded)[0]

    print(f'True Categories:'.ljust(21,' '), f'{true_categories} - {true_categories[0]}\n')
    print(f'Predicted Categories: {predicted_categories} - {predicted_categories[0]}\n')
    print(f'Abstract: {text}\n\n')
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# True Categories:      ('soft',) - soft
#
# Predicted Categories: ('soft',) - soft
#
# Abstract: Разработка системы предотвращения аварийных ситуаций при 3D печати
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# True Categories:      ('nir',) - nir
#
# Predicted Categories: ('nir',) - nir
#
# Abstract: Оценка частоты сбоев бортовой аппаратуры с учетом помехозащищенного кодирования
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# True Categories:      ('soft',) - soft
#
# Predicted Categories: ('soft',) - soft
#
# Abstract: Разработка web-интерфейса для управления лабораторным сетевым оборудованием
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# True Categories:      ('nir',) - nir
#
# Predicted Categories: ('soft',) - soft
#
# Abstract: Исследование характеристик МОП-транзисторов с ионнолегированным каналом для фоточувствительных ПЗС БИС с помощью средств САПР
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# True Categories:      ('soft',) - soft
#
# Predicted Categories: ('soft',) - soft
#
# Abstract: Разработка web-интерфейса для управления лабораторным сетевым оборудованием

# %%
import psycopg2

con = psycopg2.connect(
  database="db_dsa", 
  user="udsa", 
  password="P@ssword2021", 
  host="92.242.58.173", 
  port="1984"
)

print("Database opened successfully")
# Out:
# Database opened successfully

# %%
cur = con.cursor()
cur.execute('''CREATE TABLE PROJECTS_ARCHIVE  
     (ID INT,
     NUMBER INT,
     VACANCIES INT,
     NAME TEXT,
     TYPE TEXT,
     TYPEDESC TEXT,
     TYPEID INT,
     STATUSID INT,
     DATACREATED TEXT,
     FACULTYID INT);''')

print("Table created successfully")
con.commit()
# Out:
# Table created successfully

# %%
import requests
response = requests.get('https://devcabinet.miem.vmnet.top/public-api/projects/archive')
posts = response.json()
posts['data']
# Out:
# [{'id': 209,
#   'number': None,
#   'vacancies': 3,
#   'nameRus': 'Создание фрезерного станка для производства печатных плат',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': '',
#   'head': '',
#   'team': [],
#   'dateCreated': '11.05.2020 19:35:20',
#   'vacancyData': ['Проектировщик - 1', 'Механик - 1', 'Электронщик - 1'],
#   'desc': None,
#   'hoursCount': 0.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 210,
#   'number': None,
#   'vacancies': 0,
#   'nameRus': 'Система мониторинга натяжения такелажа на яхтах',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': '',
#   'head': '',
#   'team': [],
#   'dateCreated': '11.05.2020 20:39:18',
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 0.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 349,
#   'number': None,
#   'vacancies': 0,
#   'nameRus': 'Разработка программы для считывания нотной записи с изображения',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': '',
#   'head': '',
#   'team': [],
#   'dateCreated': '11.07.2020 12:53:00',
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 0.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 550,
#   'number': None,
#   'vacancies': 0,
#   'nameRus': 'Проект для тестирования подачи заявки',
#   'type': 'startup',
#   'typeDesc': 'Стартап',
#   'typeId': 4,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': '',
#   'head': '',
#   'team': [],
#   'dateCreated': '22.11.2020 19:45:10',
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 0.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 6,
#   'number': 19029,
#   'vacancies': 0,
#   'nameRus': 'Программный модуль для управления кредитными рисками банка',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Давыдов Вячеслав Анатольевич',
#   'head': 'Давыдов Вячеслав Анатольевич',
#   'team': ['Самоделкина М.В.   ',
#    'Ремизова А.П.   ',
#    'Солодянкин А.А.   ',
#    'Подчезерцев А.Е.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 998.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 10,
#   'number': 19048,
#   'vacancies': 0,
#   'nameRus': 'Разработка программного обеспечения, реализующего безопасную почтовую систему в сети Интернет',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Сергеев Антон Валерьевич',
#   'head': 'Минченков Виктор Олегович',
#   'team': ['Ерофеева А.Е.   ', 'Лысыченко Е.Ю.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 423.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 25,
#   'number': 19110,
#   'vacancies': 0,
#   'nameRus': 'Цифровой след',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Королев Денис Александрович',
#   'head': 'Сластников Сергей Александрович',
#   'team': ['Григорян К.М.   ', 'Шульгин М.А.   ', 'Кирьянова В.А.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 550.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 29,
#   'number': 19114,
#   'vacancies': 0,
#   'nameRus': 'Распознавание графиков функций',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Королев Денис Александрович',
#   'head': 'Королев Денис Александрович',
#   'team': ['Дагаева М.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 62.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 30,
#   'number': 19115,
#   'vacancies': 0,
#   'nameRus': 'Стриминг-сервис для сетевого NVR',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Королев Денис Александрович',
#   'head': 'Королев Денис Александрович',
#   'team': ['Колчанова А.В.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 160.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 166,
#   'number': 19118,
#   'vacancies': 0,
#   'nameRus': 'Антифрод - 2',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Давыдов Вячеслав Анатольевич',
#   'head': 'Воробьев Иван',
#   'team': [],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 0.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 174,
#   'number': 19122,
#   'vacancies': 0,
#   'nameRus': 'Разработка на языке Python экспериментального макета системы исследования кардиологических данных для выявления наличия респираторных заболеваний',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Позин Борис Аронович',
#   'head': 'Зимина Екатерина',
#   'team': ['Барков Г.   ', 'Мартиросян Б.   ', 'Журкина А.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 625.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 175,
#   'number': 19123,
#   'vacancies': 0,
#   'nameRus': 'Автоматизация исследования методов анализа кардиологических данных для выявления наличия сахарного диабета 2-го типа',
#   'type': 'nir',
#   'typeDesc': 'НИР',
#   'typeId': 1,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': '',
#   'head': 'Новиков Роман',
#   'team': ['Федотова А.   ', 'Спешилов М.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 372.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 183,
#   'number': 19124,
#   'vacancies': 0,
#   'nameRus': 'Автоматизированный анализ программного кода на наличие недостатков',
#   'type': 'soft-hard',
#   'typeDesc': 'Прогр-аппарат.',
#   'typeId': 3,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Сергеев Антон Валерьевич',
#   'head': 'Минченков Виктор Олегович',
#   'team': ['Тараненко А.М.   ',
#    'Труханов А.И.   ',
#    'Щербинин Д.И.   ',
#    'Еремин Г.Б.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 710.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 196,
#   'number': 19128,
#   'vacancies': 0,
#   'nameRus': 'Разработка онлайн конструктора курсов (дисциплин)',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Сергеев Антон Валерьевич',
#   'head': 'Башун Владимир Владимирович',
#   'team': ['Ракина А.С.   ',
#    'Пастухова А.А.   ',
#    'Лоскутов В.М.   ',
#    'Поздняков Ф.О.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 800.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 33,
#   'number': 19203,
#   'vacancies': 0,
#   'nameRus': 'Курс "Мультимедиа-технологии"',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Королев Денис Александрович',
#   'head': 'Королев Денис Александрович',
#   'team': [],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 0.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 195,
#   'number': 19241,
#   'vacancies': 0,
#   'nameRus': 'Разработка корпоративного портала для Ростелекома',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Овчинников Александр Алексеевич',
#   'head': 'Овчинников Александр Алексеевич',
#   'team': [],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 150.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 50,
#   'number': 19251,
#   'vacancies': 0,
#   'nameRus': 'Разработка системы взаимодействия оператора с группой мобильных роботов с помощью средств виртуальной реальности',
#   'type': 'nir',
#   'typeDesc': 'НИР',
#   'typeId': 1,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Старых Владимир Александрович',
#   'head': 'Карпова Ирина Петровна',
#   'team': ['Леушина В.В.   ', 'Рогулина А.В.   ', 'Романов А.А.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 518.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 62,
#   'number': 19278,
#   'vacancies': 0,
#   'nameRus': 'Математический анализ и машинное обучение метрологических данных систем массового сбора',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Сластников Сергей Александрович',
#   'head': 'Сластников Сергей Александрович',
#   'team': ['Луканькин А.Д.   ', 'Мансуров К.А.   ', 'Тофайли Ш.Н.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 489.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 65,
#   'number': 19283,
#   'vacancies': 0,
#   'nameRus': 'Разработка программного обеспечения по выявлению признаков нелегальной финансовой деятельности в сети Интернет',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Позин Борис Аронович',
#   'head': 'Кочнев Алексей Андреевич',
#   'team': ['Мещеряков А.   ',
#    'Шераухова А.   ',
#    'Хасянов И.   ',
#    'Горбунов Ф.   ',
#    'Мотайленко И.   ',
#    'Мотозов А.   ',
#    'Хунко М.Ф.   ',
#    'Шангичева Д.А.   ',
#    'Макарова К.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 2396.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 66,
#   'number': 19284,
#   'vacancies': 0,
#   'nameRus': 'Автоматизация исследования методов анализа кардиологических данных для неинвазивного выявления уровня глюкозы в крови',
#   'type': 'nir',
#   'typeDesc': 'НИР',
#   'typeId': 1,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Позин Борис Аронович',
#   'head': 'Новиков Роман',
#   'team': ['Козловский М.   ',
#    'Парулава Ш.   ',
#    'Оралков А.   ',
#    'Сидоров М.А.   ',
#    'Ганиев Р.   ',
#    'Чадженович Д.   ',
#    'Булатов И.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 1460.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 74,
#   'number': 19293,
#   'vacancies': 0,
#   'nameRus': 'Киоск саморегистрации для участников конференции',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Романов Александр Юрьевич',
#   'head': 'Попов Дмитрий Александрович',
#   'team': ['Чибисова Т.К.   ',
#    'Рогова В.М.   ',
#    'Магомедов Ш.Г.   ',
#    'Типун Н.А.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 699.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 75,
#   'number': 19294,
#   'vacancies': 0,
#   'nameRus': 'Web-приложение для управления проектной деятельностью',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Старых Владимир Александрович',
#   'head': 'Рысаков Святослав Викторович',
#   'team': [],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 0.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 158,
#   'number': 19297,
#   'vacancies': 0,
#   'nameRus': 'Автоматизация исследования методов анализа кардиологических данных для выявления наличия респираторных заболеваний на основе использования ПО IBM SPSS',
#   'type': 'nir',
#   'typeDesc': 'НИР',
#   'typeId': 1,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Позин Борис Аронович',
#   'head': 'Зимина Екатерина',
#   'team': ['Губайдуллина А.   ',
#    'Рулина Д.Э.   ',
#    'Богомолов Д.   ',
#    'Баранов Д.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 1010.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 184,
#   'number': 19302,
#   'vacancies': 0,
#   'nameRus': 'Разработка робота-собаки',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Белов Александр Владимирович',
#   'head': 'Лежнев Евгений Владимирович',
#   'team': [],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 0.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 77,
#   'number': 19402,
#   'vacancies': 0,
#   'nameRus': 'Анализ методов реализации квантовых алгоритмов на квантовой программной платформе “QISKit” от IBM',
#   'type': 'nir',
#   'typeDesc': 'НИР',
#   'typeId': 1,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Выборный Евгений Викторович',
#   'head': 'Лубенец Елена Рубеновна',
#   'team': ['Сандул В.П.   ', 'Чиков А.П.   ', 'Кузнецов С.А.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 710.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 78,
#   'number': 19403,
#   'vacancies': 0,
#   'nameRus': 'Анализ методов реализации квантовых информационных протоколов на квантовой программной платформе “QISKit” от IBM-Q',
#   'type': 'nir',
#   'typeDesc': 'НИР',
#   'typeId': 1,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Выборный Евгений Викторович',
#   'head': 'Лубенец Елена Рубеновна',
#   'team': ['Кравцова М.А.   ', 'Овсянников М.А.   ', 'Алексухин В.И.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 670.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 81,
#   'number': 19407,
#   'vacancies': 0,
#   'nameRus': 'Баллистическое обеспечение проекта СОДА',
#   'type': 'nir',
#   'typeDesc': 'НИР',
#   'typeId': 1,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Аксенов Сергей Алексеевич',
#   'head': 'Бобер Станислав Алексеевич',
#   'team': ['Белых М.В.   ',
#    'Нугманов А.М.   ',
#    'Паутова С.В.   ',
#    'Корнеев А.В.   ',
#    'Быков А.А.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 1208.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 83,
#   'number': 19411,
#   'vacancies': 0,
#   'nameRus': 'Инвариантные алгебраические кривые квадратичных динамических систем',
#   'type': 'nir',
#   'typeDesc': 'НИР',
#   'typeId': 1,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Выборный Евгений Викторович',
#   'head': 'Белова Мария Владимировна',
#   'team': ['Петелина И.Г.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 196.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 86,
#   'number': 19420,
#   'vacancies': 0,
#   'nameRus': 'Квазиклассическое приближение для разностных уравнений',
#   'type': 'nir',
#   'typeDesc': 'НИР',
#   'typeId': 1,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Выборный Евгений Викторович',
#   'head': 'Выборный Евгений Викторович',
#   'team': ['Румянцева С.В.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 198.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 87,
#   'number': 19423,
#   'vacancies': 0,
#   'nameRus': 'Методы градиентного типа для решения задач выпуклой оптимизации',
#   'type': 'nir',
#   'typeDesc': 'НИР',
#   'typeId': 1,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Артамонов Сергей Юрьевич',
#   'head': 'Артамонов Сергей Юрьевич',
#   'team': ['Петрищева А.М.   ', 'Егорова Ю.И.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 190.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 92,
#   'number': 19438,
#   'vacancies': 0,
#   'nameRus': 'Обобщенные модули гладкости',
#   'type': 'nir',
#   'typeDesc': 'НИР',
#   'typeId': 1,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Артамонов Сергей Юрьевич',
#   'head': 'Артамонов Сергей Юрьевич',
#   'team': ['Боброва К.В.   ', 'Горбунова В.Н.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 320.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 94,
#   'number': 19443,
#   'vacancies': 0,
#   'nameRus': 'Построение и анализ семантических сетей',
#   'type': 'nir',
#   'typeDesc': 'НИР',
#   'typeId': 1,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Выборный Евгений Викторович',
#   'head': 'Вальба Ольга Владимировна',
#   'team': ['Серякова В.Д.   ', 'Костюшина А.А.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 370.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 95,
#   'number': 19449,
#   'vacancies': 0,
#   'nameRus': 'Проект компании Huawei: Разработка платформы для быстрого моделирования LDPC кодов на основе статистических методов',
#   'type': 'nir',
#   'typeDesc': 'НИР',
#   'typeId': 1,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Сергеев Антон Валерьевич',
#   'head': 'Иванов Федор Ильич',
#   'team': ['Четвериков И.С.   ',
#    'Билева А.А.   ',
#    'Красков В.В.   ',
#    'Мирошник В.А.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 2079.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 97,
#   'number': 19451,
#   'vacancies': 0,
#   'nameRus': 'Разработка шаблонов заданий по математическому анализу для электронной тестирующей системы',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Выборный Евгений Викторович',
#   'head': 'Выборный Евгений Викторович',
#   'team': ['Попов А.С.   ', 'Белов Д.С.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 433.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 103,
#   'number': 19461,
#   'vacancies': 0,
#   'nameRus': 'Структуры потоков жидкости в испаряющейся капле в зависимости от геометрии капли и свойств жидкости и подложки',
#   'type': 'nir',
#   'typeDesc': 'НИР',
#   'typeId': 1,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Артамонов Сергей Юрьевич',
#   'head': 'Артамонов Сергей Юрьевич',
#   'team': ['Гаврилина А.А.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 380.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 104,
#   'number': 19465,
#   'vacancies': 0,
#   'nameRus': 'Тонкие множества в гармоническом анализе',
#   'type': 'nir',
#   'typeDesc': 'НИР',
#   'typeId': 1,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Артамонов Сергей Юрьевич',
#   'head': 'Артамонов Сергей Юрьевич',
#   'team': ['Янина А.В.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 190.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 105,
#   'number': 19466,
#   'vacancies': 0,
#   'nameRus': 'Фазовые переходы в моделях распространения активации по сети',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Выборный Евгений Викторович',
#   'head': 'Вальба Ольга Владимировна',
#   'team': [],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 38.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 106,
#   'number': 19467,
#   'vacancies': 0,
#   'nameRus': 'Цифровая платформа для интеллектуального подбора мероприятий и компаньонов, исходя из предпочтений пользователя',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Выборный Евгений Викторович',
#   'head': 'Вальба Ольга Владимировна',
#   'team': ['Ванюшкин Д.А.   ', 'Савинов А.И.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 448.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 110,
#   'number': 19471,
#   'vacancies': 0,
#   'nameRus': 'Моделирование двойного электрического слоя в литий-ионных батареях с несколькими типами катионов',
#   'type': 'nir',
#   'typeDesc': 'НИР',
#   'typeId': 1,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Выборный Евгений Викторович',
#   'head': 'Будков Юрий Алексеевич',
#   'team': [],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 0.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 111,
#   'number': 19472,
#   'vacancies': 0,
#   'nameRus': 'Оптимальное управление конечномерными квантовыми системами',
#   'type': 'nir',
#   'typeDesc': 'НИР',
#   'typeId': 1,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Выборный Евгений Викторович',
#   'head': 'Лубенец Елена Рубеновна',
#   'team': ['Леоненко А.И.   ', 'Чиняков Н.А.   ', 'Нагайко С.И.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 645.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 115,
#   'number': 19477,
#   'vacancies': 0,
#   'nameRus': 'Пакет прикладного программного обеспечения для решения задач глобальной оптимизации',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Самбурский Лев Михайлович',
#   'head': 'Горчаков Андрей Юрьевич',
#   'team': [],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 0.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 116,
#   'number': 19478,
#   'vacancies': 0,
#   'nameRus': 'Объединение изображений в авиационных системах улучшенного и комбинированного видения при помощи генеративных состязательных сетей',
#   'type': 'nir',
#   'typeDesc': 'НИР',
#   'typeId': 1,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Сластников Сергей Александрович',
#   'head': 'Зонтов Юрий Владимирович',
#   'team': ['Неклюдов С.А.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 226.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 118,
#   'number': 19480,
#   'vacancies': 0,
#   'nameRus': 'Информационная среда управления проектными заявками',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Сластников Сергей Александрович',
#   'head': 'Сластников Сергей Александрович',
#   'team': [],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 36.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 122,
#   'number': 19485,
#   'vacancies': 0,
#   'nameRus': 'Исследование проблем оптимального управления запасом непрерывного продукта в схеме регенерации с переменной скоростью потребления',
#   'type': 'nir',
#   'typeDesc': 'НИР',
#   'typeId': 1,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Выборный Евгений Викторович',
#   'head': 'Шнурков Петр Викторович',
#   'team': [],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 0.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 123,
#   'number': 19486,
#   'vacancies': 0,
#   'nameRus': 'Проект компании Huawei: Разработка платформы для быстрого моделирования TPC кодов на основе статистических методов',
#   'type': 'nir',
#   'typeDesc': 'НИР',
#   'typeId': 1,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Сергеев Антон Валерьевич',
#   'head': 'Иванов Федор Ильич',
#   'team': ['Адамчук П.В.   ',
#    'Горбунов И.И.   ',
#    'Багов А.А.   ',
#    'Савенко Д.А.   ',
#    'Мирошник В.А.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 1216.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 124,
#   'number': 19487,
#   'vacancies': 0,
#   'nameRus': 'Задача многоклассовой классификации отзывов покупателей о продуктах методами машинного обучения',
#   'type': 'nir',
#   'typeDesc': 'НИР',
#   'typeId': 1,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Артамонов Сергей Юрьевич',
#   'head': 'Артамонов Сергей Юрьевич',
#   'team': ['Мотовилова П.Д.   ', 'Андрюшина О.Н.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 782.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 171,
#   'number': 19490,
#   'vacancies': 3,
#   'nameRus': 'Телеуправляемый необитаемый подводный аппарат ',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Афанасьев Валерий Николаевич',
#   'head': 'Семион Александр Александрович',
#   'team': ['Матвеев Д.С.   '],
#   'dateCreated': None,
#   'vacancyData': ['проектировщик и механик - 2',
#    'Электронщик - 1',
#    'Системный программист - 1'],
#   'desc': None,
#   'hoursCount': 0.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 181,
#   'number': 19494,
#   'vacancies': 0,
#   'nameRus': 'Исследование  проблем управления запасом дискретных и непрерывных продуктов на основе стохастических моделей регенерации',
#   'type': 'nir',
#   'typeDesc': 'НИР',
#   'typeId': 1,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Белов Александр Владимирович',
#   'head': 'Шнурков Петр Викторович',
#   'team': ['Печёрских А.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 0.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 193,
#   'number': 19500,
#   'vacancies': 0,
#   'nameRus': 'Разработка информационной системы планирования туристических поездок',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Сластников Сергей Александрович',
#   'head': 'Зонтов Юрий Владимирович',
#   'team': ['Шевченко В.П.   ',
#    'Казаков Н.П.   ',
#    'Горбатов Д.С.   ',
#    'Лизунова Е.Г.   ',
#    'Цыплакова А.А.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 541.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 198,
#   'number': 19502,
#   'vacancies': 0,
#   'nameRus': 'Верификация посадочной платформы миссии Экзомарс',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Аксенов Сергей Алексеевич',
#   'head': 'Бобер Станислав Алексеевич',
#   'team': [],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 5.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 128,
#   'number': 19608,
#   'vacancies': 0,
#   'nameRus': 'Вероятностный калькулятор отказов установок электроцентробежных насосов',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Самбурский Лев Михайлович',
#   'head': 'Стукач Олег Владимирович',
#   'team': ['Данилко А.И.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 221.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 134,
#   'number': 19624,
#   'vacancies': 3,
#   'nameRus': 'Нейросетевая модель учёта тепловой энергии города',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Самбурский Лев Михайлович',
#   'head': 'Стукач Олег Владимирович',
#   'team': ['Бахарева К.А.   ', 'Карнаухов А.Ю.   '],
#   'dateCreated': None,
#   'vacancyData': ['Back-end-разработчик - 3'],
#   'desc': None,
#   'hoursCount': 237.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 135,
#   'number': 19629,
#   'vacancies': 0,
#   'nameRus': 'Погода в МИЭМ',
#   'type': 'soft-hard',
#   'typeDesc': 'Прогр-аппарат.',
#   'typeId': 3,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Красивская Мария Игоревна',
#   'head': 'Юрин Александр',
#   'team': ['Баженова А.Д.   ',
#    'Пантелеев В.А.   ',
#    'Ковалева А.С.   ',
#    'Заверюха И.Д.   ',
#    'Пучков Л.А.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 565.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 136,
#   'number': 19630,
#   'vacancies': 3,
#   'nameRus': 'Программно-аппаратный комплекс оценки показателей надежности резервируемой радиоэлектронной аппаратуры',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Полесский Сергей Николаевич',
#   'head': 'Королев Павел Сергеевич',
#   'team': ['Кунижев И.Р.   ',
#    'Мухаметов Р.Р.   ',
#    'Мирзахматов Ш.А.У.   ',
#    'Гильманова Д.   ',
#    'Игров А.М.   '],
#   'dateCreated': None,
#   'vacancyData': ['программист - 2', 'Разработчик-исследователь - 2'],
#   'desc': None,
#   'hoursCount': 986.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 137,
#   'number': 19631,
#   'vacancies': 4,
#   'nameRus': 'Программный модуль оценки безотказности радиоэлектронных средств для комплексного проектирования',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Полесский Сергей Николаевич',
#   'head': 'Королев Павел Сергеевич',
#   'team': ['Мелков Н.А.   ',
#    'Поставцев М.В.   ',
#    'Мушатенко В.К.   ',
#    'Овчинников Д.П.   '],
#   'dateCreated': None,
#   'vacancyData': ['программист - 2', 'Разработчик-исследователь - 2'],
#   'desc': None,
#   'hoursCount': 1020.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 138,
#   'number': 19634,
#   'vacancies': 0,
#   'nameRus': 'Разработка противоугонного модуля для велотранспорта',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Полесский Сергей Николаевич',
#   'head': 'Королев Павел Сергеевич',
#   'team': ['Сивков А.А.   ',
#    'Ротай А.Д.   ',
#    'Перов Я.С.   ',
#    'Стецкевич А.М.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 816.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 142,
#   'number': 19646,
#   'vacancies': 0,
#   'nameRus': 'Разработка нательных антенн и излучателей для интернета вещей',
#   'type': 'soft-hard',
#   'typeDesc': 'Прогр-аппарат.',
#   'typeId': 3,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Елизаров Андрей Альбертович',
#   'head': 'Елизаров Андрей Альбертович',
#   'team': ['Бабинцева А.А.   ', 'Кузнецов А.Д.   ', 'Баякина Е.П.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 242.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 143,
#   'number': 19650,
#   'vacancies': 0,
#   'nameRus': 'Разработка управляющего контроллера для системы комплексной вентиляции нескольких помещений',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Полесский Сергей Николаевич',
#   'head': 'Полесский Сергей Николаевич',
#   'team': ['Клюваков Д.Д.   ',
#    'Яценко И.Ю.   ',
#    'Алиев Н.А.   ',
#    'Петин Д.М.   ',
#    'Тонков А.С.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 1350.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 145,
#   'number': 19656,
#   'vacancies': 0,
#   'nameRus': 'Умные примерочные II. Проект антенного RFID модуля',
#   'type': 'soft-hard',
#   'typeDesc': 'Прогр-аппарат.',
#   'typeId': 3,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Елизаров Андрей Альбертович',
#   'head': 'Елизаров Андрей Альбертович',
#   'team': ['Таранцев В.А.   ', 'Башкевич С.В.   ', 'Денисов М.В.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 600.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 148,
#   'number': 19660,
#   'vacancies': 0,
#   'nameRus': 'Разработка кроссплатформенной игры на Unity',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Сластников Сергей Александрович',
#   'head': 'Зонтов Юрий Владимирович',
#   'team': ['Никитин А.В.   ',
#    'Забродина Т.Н.   ',
#    'Приходов А.В.   ',
#    'Голубев Н.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 1317.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 153,
#   'number': 19665,
#   'vacancies': 0,
#   'nameRus': 'Разработка унифицированного узла обработки информации для гелиогеофизической аппаратуры',
#   'type': 'soft-hard',
#   'typeDesc': 'Прогр-аппарат.',
#   'typeId': 3,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Самбурский Лев Михайлович',
#   'head': 'Стукач Олег Владимирович',
#   'team': ['Хокшанов Н.С.   ', 'Клапышев И.А.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 1130.0,
#   'facultyId': None,
#   'thumbnail': None},
#  {'id': 154,
#   'number': 19666,
#   'vacancies': 0,
#   'nameRus': 'Исследование акустического канала утечки информации, вводимой с клавиатуры вычислительных устройств',
#   'type': 'soft',
#   'typeDesc': 'Прогр.',
#   'typeId': 2,
#   'statusId': 3,
#   'statusDesc': 'В архиве',
#   'directionHead': 'Евсютин Олег Олегович',
#   'head': 'Евсютин Олег Олегович',
#   'team': ['Тюрин И.Г.   '],
#   'dateCreated': None,
#   'vacancyData': [],
#   'desc': None,
#   'hoursCount': 134.0,
#   'facultyId': None,
#   'thumbnail': None}]

# %%
import requests
response = requests.get('https://devcabinet.miem.vmnet.top/public-api/projects/archive')
posts = response.json()
#print(posts['data'][0]['nameRus'])
cur = con.cursor()
for i in range(62):
    p1 = posts['data'][i]['id']
    p2 = posts['data'][i]['number']
    p3 = posts['data'][i]['vacancies']
    p4 = posts['data'][i]['nameRus']
    p5 = posts['data'][i]['type']
    p6 = posts['data'][i]['typeDesc']
    p7 = posts['data'][i]['typeId']
    p8 = posts['data'][i]['statusId']
    p9 = posts['data'][i]['dateCreated']
    p10 = posts['data'][i]['facultyId']
    cur.execute(
      "INSERT INTO PROJECTS_ARCHIVE (ID,NUMBER,VACANCIES,NAME,TYPE,TYPEDESC,TYPEID,STATUSID,DATACREATED,FACULTYID) VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)", (p1, p2, p3, p4, p5, p6, p7, p8, p9, p10)
    )
con.commit()
con.close()

# %% [markdown]
# # ПРОЕКТЫ НЕ АРХИВ

# %%
cur = con.cursor()
cur.execute('''CREATE TABLE PROJECTS  
     (ID INT,
     NUMBER INT,
     VACANCIES INT,
     NAME TEXT,
     TYPE TEXT,
     TYPEDESC TEXT,
     TYPEID INT,
     STATUSID INT,
     STATUSDESC TEXT,
     DIRECTIONHEAD TEXT,
     HEAD TEXT,
     DATACREATED TEXT,
     FACULTYID INT);''')

print("Table created successfully")
con.commit()
# Out:
# Table created successfully

# %%
import requests
response2 = requests.get('https://devcabinet.miem.vmnet.top/public-api/projects')
posts2 = response.json()
cur = con.cursor()
for i in range(62):
    p1 = posts2['data'][i]['id']
    p2 = posts2['data'][i]['number']
    p3 = posts2['data'][i]['vacancies']
    p4 = posts2['data'][i]['nameRus']
    p5 = posts2['data'][i]['type']
    p6 = posts2['data'][i]['typeDesc']
    p7 = posts2['data'][i]['typeId']
    p8 = posts2['data'][i]['statusId']
    p9 = posts2['data'][i]['statusDesc']
    p10 = posts2['data'][i]['directionHead']
    p11 = posts2['data'][i]['head']
    p12 = posts2['data'][i]['dateCreated']
    p13 = posts2['data'][i]['facultyId']
    cur.execute(
      "INSERT INTO PROJECTS (ID,NUMBER,VACANCIES,NAME,TYPE,TYPEDESC,TYPEID,STATUSID,STATUSDESC,DIRECTIONHEAD,HEAD,DATACREATED,FACULTYID) VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)", (p1, p2, p3, p4, p5, p6, p7, p8, p9, p10, p11, p12, p13)
    )
con.commit()
con.close()

# %%
cur = con.cursor()
for i in range(63, 324):
    p1 = posts2['data'][i]['id']
    p2 = posts2['data'][i]['number']
    p3 = posts2['data'][i]['vacancies']
    p4 = posts2['data'][i]['nameRus']
    p5 = posts2['data'][i]['type']
    p6 = posts2['data'][i]['typeDesc']
    p7 = posts2['data'][i]['typeId']
    p8 = posts2['data'][i]['statusId']
    p9 = posts2['data'][i]['statusDesc']
    p10 = posts2['data'][i]['directionHead']
    p11 = posts2['data'][i]['head']
    p12 = posts2['data'][i]['dateCreated']
    p13 = posts2['data'][i]['facultyId']
    cur.execute(
      "INSERT INTO PROJECTS (ID,NUMBER,VACANCIES,NAME,TYPE,TYPEDESC,TYPEID,STATUSID,STATUSDESC,DIRECTIONHEAD,HEAD,DATACREATED,FACULTYID) VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)", (p1, p2, p3, p4, p5, p6, p7, p8, p9, p10, p11, p12, p13)
    )
con.commit()
con.close()

# %% [markdown]
# # C ТОКЕНОМ (песочница проектов)

# %%
import requests
response3 = requests.get('https://devcabinet.miem.vmnet.top/api/sandbox', 
                         headers={'x-auth-token': 'eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9.eyJpYXQiOjE2MjE4NDE3NjAsImV4cCI6MTYyMTkyODE2MCwidXNlcm5hbWUiOiLQmNCx0LDQtdCy0LAg0JDQvdCw0YHRgtCw0YHQuNGPINCQ0LvQtdC60YHQsNC90LTRgNC-0LLQvdCwIiwiZW1haWwiOiJhYWliYWV2YUBlZHUuaHNlLnJ1Iiwic3RhZmYiOmZhbHNlLCJzdHVkZW50Ijp0cnVlfQ.nSlOUv9pOFYp3dc1DjnHdoi-HOkKlyhelqaPeI5AwmNcecVAKom1T0rB83ZsBjqOM9_k7hNyemmWNpP3nlLtm9RWRZDvOStX8yXKzpDPjQ73-tSYtjLLlkpSPiitdYlSeqAh8P7VjsGRIsZa2sEfm4H8CsZxoxykLuzzV1aVyZ4aC-x-JBDvkxLpcG05v90ZrRXEP5lMQDFpIn12UBxbw-6hT2amTwrmOvrwE10hBPOhbfDoWM34vXbxOcLI5KI41sCuOyBWmLjsE7JHsIJzfb8_uCO60zXrxAq8lDmlzm6olKgEzEZmRVlPIG6SKnYvOk2syKYFmrBmGMHCLc6141im_wJxgbTPAzlAKizGQIKQyjZgVuHzU3G87hn3c68jIdYDhn0R_lZJEQQk_fQJHJe75o6ZBIeIlFBKOaIOkvn8NKbUZL5r9C6CJB7V6Su8_bvVybuAsMNIJSDdB_eklVGQbW5aJPrRoUMxXobG7AmEN4ou4NqqB3Gb5a_CSoYNdR9jJaSewyFDDGnXrHYqokwp39mxnA--jHeV38nRrrn9ehfBDfRpq_v6s4l50WODbseUFux3xJq-NE5Zz3UD72DUqmAbrnCedJViYgr6MkfMtyGmOy6sCUm3QPqjPnmEuRIDt18AFeTZguRkB_L5de3MqYNLJCBfL3qIvXmPNOc'})
posts3 = response3.json()

# %%
posts3['data'][131]
# Out:
# {'id': 434,
#  'owner': False,
#  'status': 'po_approved',
#  'statusDesc': 'Проверено проектным офисом',
#  'nameRus': 'Электронный тензометр для такелажа яхт',
#  'head': 'Буров Василий',
#  'type': 'soft-hard',
#  'typeDesc': 'Прогр-аппарат.',
#  'dateCreated': '08.09.2020 08:52:53',
#  'team': ['не указано'],
#  'vacancies': 0}

# %%
cur = con.cursor()
cur.execute('''CREATE TABLE SANDBOX  
     (ID INT,
     STATUS TEXT,
     STATUSDESC TEXT,
     NAME TEXT,
     HEAD TEXT,
     TYPE TEXT,
     TYPEDESC TEXT,
     DATECREATED TEXT,
     VACANCIES INT);''')

print("Table created successfully")
con.commit()
# Out:
# Table created successfully

# %%
cur = con.cursor()
for i in range(131):
    p1 = posts3['data'][i]['id']
    p2 = posts3['data'][i]['status']
    p3 = posts3['data'][i]['statusDesc']
    p4 = posts3['data'][i]['nameRus']
    p5 = posts3['data'][i]['head']
    p6 = posts3['data'][i]['type']
    p7 = posts3['data'][i]['typeDesc']
    p8 = posts3['data'][i]['dateCreated']
    p9 = posts3['data'][i]['vacancies']
    cur.execute(
      "INSERT INTO SANDBOX (ID,STATUS,STATUSDESC,NAME,HEAD,TYPE,TYPEDESC,DATECREATED,VACANCIES) VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)", (p1, p2, p3, p4, p5, p6, p7, p8, p9)
    )
con.commit()
con.close()
